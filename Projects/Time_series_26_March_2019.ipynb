# %%
import pandas as pd
import numpy as np
import matplotlib as plt

df2= pd.read_csv("C:\PYTHON\ML\AAPL.csv")

# %%
df2= pd.read_csv("C:\PYTHON\ML\AAPL.csv",parse_dates=["Date"],index_col="Date")

# %%
df2.index
# Out:
# DatetimeIndex(['2014-09-29', '2014-10-06', '2014-10-13', '2014-10-20',
#                '2014-10-27', '2014-11-03', '2014-11-10', '2014-11-17',
#                '2014-11-24', '2014-12-01',
#                ...
#                '2018-01-29', '2018-02-05', '2018-02-12', '2018-02-19',
#                '2018-02-26', '2018-03-05', '2018-03-12', '2018-03-19',
#                '2018-03-26', '2018-03-29'],
#               dtype='datetime64[ns]', name='Date', length=184, freq=None)

# %%
df2['Close'].resample('Y').mean().plot(kind='bar')

# %%
# %matplotlib inline
df2['Close'].plot()

# %%
# B refer to buisness day

rng=pd.date_range(start="6/1/2016", end="6/30/2016", freq='B')

# %%
rng
# Out:
# DatetimeIndex(['2016-06-01', '2016-06-02', '2016-06-03', '2016-06-06',
#                '2016-06-07', '2016-06-08', '2016-06-09', '2016-06-10',
#                '2016-06-13', '2016-06-14', '2016-06-15', '2016-06-16',
#                '2016-06-17', '2016-06-20', '2016-06-21', '2016-06-22',
#                '2016-06-23', '2016-06-24', '2016-06-27', '2016-06-28',
#                '2016-06-29', '2016-06-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
df2.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
#
#                Volume
# Date
# 2014-09-29  142718700
# 2014-10-06  280258200
# 2014-10-13  358539800
# 2014-10-20  358532900
# 2014-10-27  220230600

# %%
#Daaset without date
df3= pd.read_csv("C:\PYTHON\ML\AAPL1.csv")

# %%
df3.head()
# Out:
#          Open        High         Low       Close   Adj Close     Volume
# 0  100.589996  100.690002   98.040001   99.620003   93.514290  142718700
# 1   99.949997  102.379997   98.309998  100.730003   94.556244  280258200
# 2  101.330002  101.779999   95.180000   97.669998   91.683792  358539800
# 3   98.320000  105.489998   98.220001  105.220001   98.771042  358532900
# 4  104.849998  108.040001  104.699997  108.000000  101.380676  220230600

# %%
rng=pd.date_range(start="4/1/2017",end="12/14/2017",freq='B')
# Note DAte range should match with the number data in column

# %%
rng
# Out:
# DatetimeIndex(['2017-04-03', '2017-04-04', '2017-04-05', '2017-04-06',
#                '2017-04-07', '2017-04-10', '2017-04-11', '2017-04-12',
#                '2017-04-13', '2017-04-14',
#                ...
#                '2017-12-01', '2017-12-04', '2017-12-05', '2017-12-06',
#                '2017-12-07', '2017-12-08', '2017-12-11', '2017-12-12',
#                '2017-12-13', '2017-12-14'],
#               dtype='datetime64[ns]', length=184, freq='B')

# %%
# To set  date as index coulmn in dataset
df3.set_index(rng,inplace= True)

# %%
df3.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2017-04-03  100.589996  100.690002   98.040001   99.620003   93.514290
# 2017-04-04   99.949997  102.379997   98.309998  100.730003   94.556244
# 2017-04-05  101.330002  101.779999   95.180000   97.669998   91.683792
# 2017-04-06   98.320000  105.489998   98.220001  105.220001   98.771042
# 2017-04-07  104.849998  108.040001  104.699997  108.000000  101.380676
#
#                Volume
# 2017-04-03  142718700
# 2017-04-04  280258200
# 2017-04-05  358539800
# 2017-04-06  358532900
# 2017-04-07  220230600

# %%
df3.shape
# Out:
# (184, 6)

# %%
df3
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2017
pad')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2017-04-09  104.849998  108.040001  104.699997  108.000000  101.380676
# 2017-04-16  118.809998  119.250000  111.269997  115.000000  108.419746
# 2017-04-23  108.290001  113.250000  104.629997  112.010002  105.600830
# 2017-04-30  118.550003  127.480003  118.430000  127.080002  120.281372
# 2017-05-07  123.879997  129.250000  122.870003  125.900002  119.164505
# 2017-05-14  125.570000  130.630005  125.169998  130.279999  123.310150
# 2017-05-21  132.600006  132.910004  129.119995  130.279999  123.825241
# 2017-05-28  125.459999  126.940002  124.480003  126.440002  120.175491
# 2017-06-04  121.500000  122.570000  112.099998  115.519997  109.796532
# 2017-06-11  111.750000  114.209999  109.769997  114.209999  109.042786
# 2017-06-18  112.730003  112.750000  109.559998  111.040001  106.016205
# 2017-06-25  111.379997  119.919998  111.000000  119.300003  114.390068
# ...

# %%
df3.asfreq('H',method='pad')
# Out:
#                            Open        High         Low       Close  \
# 2017-04-03 00:00:00  100.589996  100.690002   98.040001   99.620003
# 2017-04-03 01:00:00  100.589996  100.690002   98.040001   99.620003
# 2017-04-03 02:00:00  100.589996  100.690002   98.040001   99.620003
# 2017-04-03 03:00:00  100.589996  100.690002   98.040001   99.620003
# 2017-04-03 04:00:00  100.589996  100.690002   98.040001   99.620003
# 2017-04-03 05:00:00  100.589996  100.690002   98.040001   99.620003
# 2017-04-03 06:00:00  100.589996  100.690002   98.040001   99.620003
# 2017-04-03 07:00:00  100.589996  100.690002   98.040001   99.620003
# 2017-04-03 08:00:00  100.589996  100.690002   98.040001   99.620003
# 2017-04-03 09:00:00  100.589996  100.690002   98.040001   99.620003
# 2017-04-03 10:00:00  100.589996  100.690002   98.040001   99.620003
# 2017-04-03 11:00:00  100.589996  100.690002   98.040001   99.620003
# 2017-04-03 12:00:00  100.589996  100.690002   98.040001   99.620003
# ...

# %%
df3.asfreq('D',method='bfill')

# * 'pad' / 'ffill': propagate last valid observation forward to next
      valid
  #  * 'backfill' / 'bfill': use NEXT valid observation to fill
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2017-04-03  100.589996  100.690002   98.040001   99.620003   93.514290
# 2017-04-04   99.949997  102.379997   98.309998  100.730003   94.556244
# 2017-04-05  101.330002  101.779999   95.180000   97.669998   91.683792
# 2017-04-06   98.320000  105.489998   98.220001  105.220001   98.771042
# 2017-04-07  104.849998  108.040001  104.699997  108.000000  101.380676
# 2017-04-08  108.220001  110.300003  107.720001  109.010002  102.328766
# 2017-04-09  108.220001  110.300003  107.720001  109.010002  102.328766
# 2017-04-10  108.220001  110.300003  107.720001  109.010002  102.328766
# 2017-04-11  109.019997  114.190002  108.400002  114.180000  107.646675
# 2017-04-12  114.269997  117.570000  113.300003  116.470001  109.805626
# 2017-04-13  116.849998  119.750000  116.620003  118.930000  112.124863
# 2017-04-14  118.809998  119.250000  111.269997  115.000000  108.419746
# ...

# %%
#generating date /Time index with period argument


rng = pd.date_range('1/1/2011', periods=5, freq='D')
rng
# Out:
# DatetimeIndex(['2011-01-01', '2011-01-02', '2011-01-03', '2011-01-04',
#                '2011-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
# Creating dataset with column index of Date with Random values range 

import numpy as np
ts = pd.Series(np.random.randint(91,100,len(rng)), index=rng)
ts.head(30)
# Out:
# 2011-01-01    91
# 2011-01-02    96
# 2011-01-03    92
# 2011-01-04    93
# 2011-01-05    92
# Freq: D, dtype: int32

# %%
ts["2011-01-05"]
# Out:
# 92

# %%
df3["2017-12-01":"2017-12-10"].Low.plot()
# Filter Price value in date range between (Dec 1- 10, 2017 for Low Cloumn) then to plot a graph

# %%
df2.sort_index(axis=1,inplace=True,ascending=True)
df2.head()
# Out:
#              Adj Close       Close        High         Low        Open  \
# Date
# 2014-09-29   93.514290   99.620003  100.690002   98.040001  100.589996
# 2014-10-06   94.556244  100.730003  102.379997   98.309998   99.949997
# 2014-10-13   91.683792   97.669998  101.779999   95.180000  101.330002
# 2014-10-20   98.771042  105.220001  105.489998   98.220001   98.320000
# 2014-10-27  101.380676  108.000000  108.040001  104.699997  104.849998
#
#                Volume
# Date
# 2014-09-29  142718700
# 2014-10-06  280258200
# 2014-10-13  358539800
# 2014-10-20  358532900
# 2014-10-27  220230600
