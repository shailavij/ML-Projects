# %% [markdown]
# <a href="https://colab.research.google.com/github/shailavij/ML-Projects/blob/master/Pump_sensor_Time_series_Analysis_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import all pacakages

from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pyplot import rcParams
rcParams['figure.figsize']=12,8
from sklearn import preprocessing
# %matplotlib inline
from keras.models import Sequential
from keras.layers import Dense , LSTM
seed= 7
np.random.seed(seed)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Using TensorFlow backend.

# %%
# !pip3 install --user scipy==1.2.0
# Out:
# ...
#      |████████████████████████████████| 26.6MB 37.0MB/s
# ...
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...

# %%
df1=pd.read_csv('drive/My Drive/DL_DATASet/sensor.csv',index_col='timestamp',parse_dates=['timestamp'])

# %%
df1.head(10)
# Out:
#                      Unnamed: 0  sensor_00  ...  sensor_51  machine_status
# timestamp                                   ...
# 2018-04-01 00:00:00           0   2.465394  ...   201.3889          NORMAL
# 2018-04-01 00:01:00           1   2.465394  ...   201.3889          NORMAL
# 2018-04-01 00:02:00           2   2.444734  ...   203.7037          NORMAL
# 2018-04-01 00:03:00           3   2.460474  ...   203.1250          NORMAL
# 2018-04-01 00:04:00           4   2.445718  ...   201.3889          NORMAL
# 2018-04-01 00:05:00           5   2.453588  ...   201.6782          NORMAL
# 2018-04-01 00:06:00           6   2.455556  ...   200.2315          NORMAL
# 2018-04-01 00:07:00           7   2.449653  ...   201.0995          NORMAL
# 2018-04-01 00:08:00           8   2.463426  ...   201.6782          NORMAL
# 2018-04-01 00:09:00           9   2.445718  ...   200.8102          NORMAL
#
# [10 rows x 54 columns]

# %%
df1.shape
# Out:
# (220320, 54)

# %%
df1.describe()
# Out:
#           Unnamed: 0      sensor_00  ...      sensor_50      sensor_51
# count  220320.000000  210112.000000  ...  143303.000000  204937.000000
# mean   110159.500000       2.372221  ...     183.049260     202.699667
# std     63601.049991       0.412227  ...      65.258650     109.588607
# min         0.000000       0.000000  ...      27.488426      27.777779
# 25%     55079.750000       2.438831  ...     167.534700     179.108800
# 50%    110159.500000       2.456539  ...     193.865700     197.338000
# 75%    165239.250000       2.499826  ...     219.907400     216.724500
# max    220319.000000       2.549016  ...    1000.000000    1000.000000
#
# [8 rows x 53 columns]

# %%
# Missing value in each column
df1.isnull().sum()
# Out:
# Unnamed: 0             0
# sensor_00          10208
# sensor_01            369
# sensor_02             19
# sensor_03             19
# sensor_04             19
# sensor_05             19
# sensor_06           4798
# sensor_07           5451
# sensor_08           5107
# sensor_09           4595
# sensor_10             19
# sensor_11             19
# sensor_12             19
# sensor_13             19
# sensor_14             21
# sensor_15         220320
# sensor_16             31
# sensor_17             46
# sensor_18             46
# sensor_19             16
# sensor_20             16
# sensor_21             16
# sensor_22             41
# sensor_23             16
# sensor_24             16
# sensor_25             36
# sensor_26             20
# sensor_27             16
# sensor_28             16
# sensor_29             72
# sensor_30            261
# sensor_31             16
# sensor_32             68
# sensor_33             16
# sensor_34             16
# sensor_35             16
# ...

# %%
df1.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df1.head(10)
# Out:
#                      sensor_00  sensor_01  ...  sensor_51  machine_status
# timestamp                                  ...
# 2018-04-01 00:00:00   2.465394   47.09201  ...   201.3889          NORMAL
# 2018-04-01 00:01:00   2.465394   47.09201  ...   201.3889          NORMAL
# 2018-04-01 00:02:00   2.444734   47.35243  ...   203.7037          NORMAL
# 2018-04-01 00:03:00   2.460474   47.09201  ...   203.1250          NORMAL
# 2018-04-01 00:04:00   2.445718   47.13541  ...   201.3889          NORMAL
# 2018-04-01 00:05:00   2.453588   47.09201  ...   201.6782          NORMAL
# 2018-04-01 00:06:00   2.455556   47.04861  ...   200.2315          NORMAL
# 2018-04-01 00:07:00   2.449653   47.13541  ...   201.0995          NORMAL
# 2018-04-01 00:08:00   2.463426   47.09201  ...   201.6782          NORMAL
# 2018-04-01 00:09:00   2.445718   47.17882  ...   200.8102          NORMAL
#
# [10 rows x 53 columns]

# %%
# TO check duplicate rows in dataset
# Select duplicate rows except first occurrence based on all columns
duplicaterowDF= df1[df1.duplicated()]
print("Total duplicated Row except first occurrence based on all columns")
duplicaterowDF.shape
# Out:
# Total duplicated Row except first occurrence based on all columns
# (2876, 53)

# %%
#remove duplicate rows in training dataset, except first occurenece
df1.drop_duplicates(keep='first',inplace=True)

# %%
df1.shape
# Out:
# (217444, 53)

# %%
df1['machine_status'].value_counts()
# Out:
# NORMAL        203169
# RECOVERING     14268
# BROKEN             7
# Name: machine_status, dtype: int64

# %%
import seaborn as sns
sns.countplot(y=df1['machine_status'])

# %%
# Filling missing value by mean
for col in df1.columns[0:-1]:
    df1[col] = df1[col].fillna(df1[col].mean())

# %%
df1.isnull().sum()
# Out:
# sensor_00              0
# sensor_01              0
# sensor_02              0
# sensor_03              0
# sensor_04              0
# sensor_05              0
# sensor_06              0
# sensor_07              0
# sensor_08              0
# sensor_09              0
# sensor_10              0
# sensor_11              0
# sensor_12              0
# sensor_13              0
# sensor_14              0
# sensor_15         217444
# sensor_16              0
# sensor_17              0
# sensor_18              0
# sensor_19              0
# sensor_20              0
# sensor_21              0
# sensor_22              0
# sensor_23              0
# sensor_24              0
# sensor_25              0
# sensor_26              0
# sensor_27              0
# sensor_28              0
# sensor_29              0
# sensor_30              0
# sensor_31              0
# sensor_32              0
# sensor_33              0
# sensor_34              0
# sensor_35              0
# sensor_36              0
# ...

# %%
df1.dropna(axis=1,inplace=True)
df1.shape
# Out:
# (217444, 52)

# %%
df1.isnull().sum()
# Out:
# sensor_00         0
# sensor_01         0
# sensor_02         0
# sensor_03         0
# sensor_04         0
# sensor_05         0
# sensor_06         0
# sensor_07         0
# sensor_08         0
# sensor_09         0
# sensor_10         0
# sensor_11         0
# sensor_12         0
# sensor_13         0
# sensor_14         0
# sensor_16         0
# sensor_17         0
# sensor_18         0
# sensor_19         0
# sensor_20         0
# sensor_21         0
# sensor_22         0
# sensor_23         0
# sensor_24         0
# sensor_25         0
# sensor_26         0
# sensor_27         0
# sensor_28         0
# sensor_29         0
# sensor_30         0
# sensor_31         0
# sensor_32         0
# sensor_33         0
# sensor_34         0
# sensor_35         0
# sensor_36         0
# sensor_37         0
# sensor_38         0
# sensor_39         0
# sensor_40         0
# sensor_41         0
# sensor_42         0
# sensor_43         0
# sensor_44         0
# sensor_45         0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 217444 entries, 2018-04-01 00:00:00 to 2018-08-31 23:59:00
# Data columns (total 52 columns):
# sensor_00         217444 non-null float64
# sensor_01         217444 non-null float64
# sensor_02         217444 non-null float64
# sensor_03         217444 non-null float64
# sensor_04         217444 non-null float64
# sensor_05         217444 non-null float64
# sensor_06         217444 non-null float64
# sensor_07         217444 non-null float64
# sensor_08         217444 non-null float64
# sensor_09         217444 non-null float64
# sensor_10         217444 non-null float64
# sensor_11         217444 non-null float64
# sensor_12         217444 non-null float64
# sensor_13         217444 non-null float64
# sensor_14         217444 non-null float64
# sensor_16         217444 non-null float64
# sensor_17         217444 non-null float64
# sensor_18         217444 non-null float64
# sensor_19         217444 non-null float64
# ...

# %%
# EDA
df2=df1.copy()
df2.head(10)
# Out:
#                      sensor_00  sensor_01  ...  sensor_51  machine_status
# timestamp                                  ...
# 2018-04-01 00:00:00   2.465394   47.09201  ...   201.3889          NORMAL
# 2018-04-01 00:02:00   2.444734   47.35243  ...   203.7037          NORMAL
# 2018-04-01 00:03:00   2.460474   47.09201  ...   203.1250          NORMAL
# 2018-04-01 00:04:00   2.445718   47.13541  ...   201.3889          NORMAL
# 2018-04-01 00:05:00   2.453588   47.09201  ...   201.6782          NORMAL
# 2018-04-01 00:06:00   2.455556   47.04861  ...   200.2315          NORMAL
# 2018-04-01 00:07:00   2.449653   47.13541  ...   201.0995          NORMAL
# 2018-04-01 00:08:00   2.463426   47.09201  ...   201.6782          NORMAL
# 2018-04-01 00:09:00   2.445718   47.17882  ...   200.8102          NORMAL
# 2018-04-01 00:10:00   2.464410   47.48264  ...   199.9421          NORMAL
#
# [10 rows x 52 columns]

# %%
df2['Date']=df2.index
df2.shape
# Out:
# (217444, 53)

# %%
df2.head()
# Out:
#                      sensor_00  sensor_01  ...  machine_status                Date
# timestamp                                  ...
# 2018-04-01 00:00:00   2.465394   47.09201  ...          NORMAL 2018-04-01 00:00:00
# 2018-04-01 00:02:00   2.444734   47.35243  ...          NORMAL 2018-04-01 00:02:00
# 2018-04-01 00:03:00   2.460474   47.09201  ...          NORMAL 2018-04-01 00:03:00
# 2018-04-01 00:04:00   2.445718   47.13541  ...          NORMAL 2018-04-01 00:04:00
# 2018-04-01 00:05:00   2.453588   47.09201  ...          NORMAL 2018-04-01 00:05:00
#
# [5 rows x 53 columns]

# %%
# EDA
values=df2.values
# specify columns to plot
groups = [0, 1, 2, 3, 5, 6, 7]
i = 1
# plot each column
plt.figure()
for group in groups:
	plt.subplot(len(groups), 1, i)
	plt.plot(values[:, group])
	plt.title(df2.columns[group], y=0.5, loc='right')
	i += 1
plt.show()

# %%
##preprocess the Machine status with label encoding
from sklearn.preprocessing import LabelEncoder
values=df1.values
encoder= LabelEncoder()

values[:,-1]= encoder.fit_transform(values[:,-1])
values[:,-1]
print(values[:,-1])
# Out:
# [1 1 1 ... 1 1 1]

# %% [markdown]
# # Machine status code : Normal = 1 , recovering=2 , Broken =0

# %%
# Update new column in "MAchine code" 
df1["Machine_code"]=values[:,-1]
df1.tail(3)
# Out:
#                      sensor_00  sensor_01  ...  machine_status  Machine_code
# timestamp                                  ...
# 2018-08-31 23:57:00   2.396528   47.69965  ...          NORMAL             1
# 2018-08-31 23:58:00   2.406366   47.69965  ...          NORMAL             1
# 2018-08-31 23:59:00   2.396528   47.69965  ...          NORMAL             1
#
# [3 rows x 53 columns]

# %%
# TO check in which period machine was recovering
df1.loc[df1["machine_status"]=="RECOVERING",["machine_status","Machine_code"]].head()
# Out:
#                     machine_status Machine_code
# timestamp
# 2018-04-12 21:56:00     RECOVERING            2
# 2018-04-12 21:57:00     RECOVERING            2
# 2018-04-12 21:58:00     RECOVERING            2
# 2018-04-12 21:59:00     RECOVERING            2
# 2018-04-12 22:00:00     RECOVERING            2

# %%
# TO check in which period machine was Normal
df1.loc[df1["machine_status"]=="NORMAL",["machine_status","Machine_code"]].head()
# Out:
#                     machine_status Machine_code
# timestamp
# 2018-04-01 00:00:00         NORMAL            1
# 2018-04-01 00:02:00         NORMAL            1
# 2018-04-01 00:03:00         NORMAL            1
# 2018-04-01 00:04:00         NORMAL            1
# 2018-04-01 00:05:00         NORMAL            1

# %%
# TO check in which period machine was broken
df1.loc[df1["machine_status"]=="BROKEN",["machine_status","Machine_code"]].head()
# Out:
#                     machine_status Machine_code
# timestamp
# 2018-04-12 21:55:00         BROKEN            0
# 2018-04-18 00:30:00         BROKEN            0
# 2018-05-19 03:18:00         BROKEN            0
# 2018-05-25 00:30:00         BROKEN            0
# 2018-06-28 22:00:00         BROKEN            0

# %%
#overview of all sensors in month of April , May to check if there is some interesting pattern

df1[(df1.index.month>=4) & (df1.index.month<=5) ].plot(figsize=(15,120),subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fc525e8c828>,
# ...
#       dtype=object)

# %% [markdown]
# Its observes that , Within 2 month (april, May) month pump was broken for 4 times. Lets grab data for 2 months between  April and end of May to train the model

# %%
# Check some sensors pattern with machine status

df1[["sensor_00", "Machine_code"]].plot(figsize=(15,10),subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fc525574c50>,
# ...
#       dtype=object)

# %%
df1.head(2)
# Out:
#                      sensor_00  sensor_01  ...  machine_status  Machine_code
# timestamp                                  ...
# 2018-04-01 00:00:00   2.465394   47.09201  ...          NORMAL             1
# 2018-04-01 00:02:00   2.444734   47.35243  ...          NORMAL             1
#
# [2 rows x 53 columns]

# %%
# Drop Machine_status_column
df1.drop("machine_status",axis=1,inplace=True)
df1.columns
# Out:
# Index(['sensor_00', 'sensor_01', 'sensor_02', 'sensor_03', 'sensor_04',
#        'sensor_05', 'sensor_06', 'sensor_07', 'sensor_08', 'sensor_09',
#        'sensor_10', 'sensor_11', 'sensor_12', 'sensor_13', 'sensor_14',
#        'sensor_16', 'sensor_17', 'sensor_18', 'sensor_19', 'sensor_20',
#        'sensor_21', 'sensor_22', 'sensor_23', 'sensor_24', 'sensor_25',
#        'sensor_26', 'sensor_27', 'sensor_28', 'sensor_29', 'sensor_30',
#        'sensor_31', 'sensor_32', 'sensor_33', 'sensor_34', 'sensor_35',
#        'sensor_36', 'sensor_37', 'sensor_38', 'sensor_39', 'sensor_40',
#        'sensor_41', 'sensor_42', 'sensor_43', 'sensor_44', 'sensor_45',
#        'sensor_46', 'sensor_47', 'sensor_48', 'sensor_49', 'sensor_50',
#        'sensor_51', 'Machine_code'],
#       dtype='object')

# %%
df1.head(2)
# Out:
#                      sensor_00  sensor_01  ...  sensor_51  Machine_code
# timestamp                                  ...
# 2018-04-01 00:00:00   2.465394   47.09201  ...   201.3889             1
# 2018-04-01 00:02:00   2.444734   47.35243  ...   203.7037             1
#
# [2 rows x 52 columns]

# %%
# normalize feature
# scale the data

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
norm= scaler.fit_transform(df1)
norm[5500]
# Out:
# array([0.96372051, 0.84085688, 0.80834878, 0.65445011, 0.80647012,
#        0.85419253, 0.59694185, 0.69466585, 0.62760235, 0.6047452 ,
#        0.53663021, 0.7906625 , 0.74367267, 0.03155057, 0.83294975,
#        0.62779119, 0.77480358, 0.52710306, 0.75659205, 0.88970522,
#        0.77540596, 0.84354236, 0.77366182, 0.6293101 , 0.93527987,
#        0.70027702, 0.23438395, 0.43931933, 0.57707819, 0.41087963,
#        0.52639293, 0.44711042, 0.38441979, 0.2665757 , 0.4209539 ,
#        0.69878694, 0.47443191, 0.04966886, 0.02216749, 0.07823311,
#        0.02216428, 0.02218936, 0.03186441, 0.00653401, 0.0285433 ,
#        0.03448275, 0.03350785, 0.2827026 , 0.07468606, 0.18565905,
#        0.19047623, 0.5       ])

# %%
# convert times series into supervised form 

def to_supervised(df1,dropNa = True,lag = 1):
    df2 = pd.DataFrame(df1)
    column = []
    column.append(df2)
    for i in range(1,lag+1):
        column.append(df2.shift(-i))
    df2 = pd.concat(column,axis=1)
    df2.dropna(inplace = True)
    features = df1.shape[1]
    df2 = df2.values
    supervised_data = df2[:,:features*lag]
    supervised_data = np.column_stack( [supervised_data, df2[:,features*lag]])
    return supervised_data

# %%
timeSteps = 3

supervised = to_supervised(norm,lag=timeSteps)
pd.DataFrame(supervised).head()
supervised.shape
# Out:
# (217441, 157)

# %%
#Define and Fit Model

# spiltting the data
# training on only first 2 months of data

features=df2.shape[1]
n_train_hr=200*24

X = supervised[:,:features*2]
Y = supervised[:,features*2]

x_train = X[:n_train_hr,:]
x_test = X[n_train_hr:,:]
y_train = Y[:n_train_hr]
y_test = Y[n_train_hr:]

print (x_train.shape,y_train.shape,x_test.shape,y_test.shape)
#x_train.head(2)
# Out:
# (4800, 106) (4800,) (212641, 106) (212641,)

# %%
##convert data to fit for lstm
# reshape input to be 3D [samples, timesteps, features]

x_train = x_train.reshape(x_train.shape[0], 2, features)
x_test = x_test.reshape(x_test.shape[0], 2, features)

print( x_train.shape,x_test.shape)
# Out:
# (4800, 2, 53) (212641, 2, 53)

# %%
#define the model

model = Sequential()
model.add( LSTM( 50, input_shape = ( x_train.shape[1],x_train.shape[2]) ) )
model.add( Dense(1) )

model.compile( loss = "mae", optimizer = "adam")

history =  model.fit( x_train,y_train, validation_data = (x_test,y_test), epochs = 500 , batch_size = 124, verbose = 2, shuffle = False)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# ...

# %%
## plot history

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.yticks([])
plt.xticks([])
plt.title("loss during training")
plt.show()

# %%
#Evaluate Model

#scale back the prediction to orginal scale

# make a prediction
y_pred = model.predict(x_test)
